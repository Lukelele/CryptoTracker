# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import torch
import beacon

# %%
plt.style.use("dark_background")

# %%
# Replace 'LTC-USD' with the desired Yahoo Finance ticker symbol for Litecoin
symbol = 'LTC-GBP'
df = yf.download(symbol, start="2020-10-10", end="2022-01-01")
Open = df["Open"]
High = df["High"]
Low = df["Low"]
Close = df["Close"]
Volume = df["Volume"]
df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 2020-10-10  36.624027  38.631283  36.624027  37.491756  37.491756  2132043535
# 2020-10-11  37.487019  39.271927  37.449013  38.929657  38.929657  1996141263
# 2020-10-12  38.843555  39.436939  38.043495  38.840435  38.840435  2025619095
# 2020-10-13  38.793915  38.793915  37.875839  38.609608  38.609608  1683659478
# 2020-10-14  38.661053  39.104877  37.947197  38.307774  38.307774  1701157034

# %%
fig, ax = plt.subplots(1, 2, figsize=[12, 4])
ax[0].plot(df["Close"])
ax[0].set_title("Closing Price")
ax[1].plot(df["Volume"])
ax[1].set_title("Volume")
# Out:
# Text(0.5, 1.0, 'Volume')

# %%
normalised_close = Close / Close.max()
normalised_volume = Volume / Volume.max()

plt.plot(normalised_close, label="Close")
plt.plot(normalised_volume, label="Volume", c="white", alpha=0.5)
plt.legend()

# %%
price_volume_ratio = normalised_volume / normalised_close
normalised_ratio = price_volume_ratio / price_volume_ratio.max()

plt.plot(normalised_close, label="Close")
plt.plot(normalised_ratio, label="Volume to Price Ratio", alpha=0.5)
plt.legend()
